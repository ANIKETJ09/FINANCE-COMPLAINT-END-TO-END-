# %%
# Out:
# ERROR:absl:Execution 111 failed.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/iNeuron_Private_Intelligence_Limited/project_neuron/finance-complaint/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/iNeuron_Private_Intelligence_Limited/project_neuron/finance-complaint/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~/iNeuron_Private_Intelligence_Limited/project_neuron/finance-complaint/venv/lib/python3.7/site-packages/tfx/orchestration/beam/beam_dag_runner.py in process(self, element, *signals)
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#
# ...

# %%
# !ls /home/avnish/iNeuron_Private_Intelligence_Limited/project_neuron/finance-complaint/notebooks/census_consumer_complaint_data/data_source/feature_store/
# Out:
# ls: cannot access '/home/avnish/iNeuron_Private_Intelligence_Limited/project_neuron/finance-complaint/notebooks/census_consumer_complaint_data/data_source/feature_store/': No such file or directory
